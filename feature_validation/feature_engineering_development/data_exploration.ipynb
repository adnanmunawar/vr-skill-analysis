# %%
# !pip install intervaltree

# %%
import h5py
import cv2

fname = 'drive/MyDrive/Colab Notebooks/20220302_132332.hdf5'
f = h5py.File(fname, 'r')
f.keys()
# Out:
# <KeysViewHDF5 ['burr_change', 'data', 'metadata', 'voxels_removed']>

# %%
f.keys()
data = f['data']
data.keys()
metadata = f['metadata']
metadata.keys()
# Out:
# <KeysViewHDF5 ['README', 'baseline', 'camera_extrinsic', 'camera_intrinsic', 'voxel_volume']>

# %%
vox = f['burr_change']
print(data)
# Out:
# <HDF5 group "/data" (7 members)>

# %%
img = data['l_img']
print(img.shape)

time = data['time']
print(time.shape)
pose_drill = data['pose_mastoidectomy_drill']
print(pose_drill.shape)
pose_cam = data['pose_main_camera']
print(pose_cam.shape)
segm = data['segm']
print(segm.shape)
# Out:
# (180, 480, 640, 3)
# (180,)
# (180, 7)
# (180, 7)
# (180, 480, 640, 3)

# %%
t = data['r_img']
print(t.shape)
print(t[:])
# Out:
# (180, 480, 640, 3)
# [[[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   ...
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]]
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
# ...
